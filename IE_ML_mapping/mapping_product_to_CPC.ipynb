# %%
import ML_mapping

# %%
self = ML_mapping.Mapping(reference_classification='CPC 2.1',
                          transformer_model='all-MiniLM-L6-v2',
                          number_of_guesses=5)

# %%
self.match_inputs(['OIL_Boiler'])
self.calculate_scores()
self.format_results()
# Out:
#                  code sector            sector similarity
# product    order
# OIL_Boiler 1           33360           Gas oil   0.572717
#            2            3336           Gas oil   0.572717
#            3           33370  Fuel oils n.e.c.   0.522871
#            4            3337  Fuel oils n.e.c.   0.522871
#            5           21671  Olive oil, crude   0.492022
